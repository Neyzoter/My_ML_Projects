# %%
##数据集使用的是波士顿房价的数据集
from mlxtend.regressor import StackingRegressor
from mlxtend.data import boston_housing_data
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.svm import SVR
import matplotlib.pyplot as plt
import numpy as np

# 生成一个样本数据集
np.random.seed(1)
X = np.sort(5 * np.random.rand(40, 1), axis=0)
y = np.sin(X).ravel()
y[::5] += 3 * (0.5 - np.random.rand(8))

from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso
# 初始化模型
lr = LinearRegression()
svr_lin = SVR(kernel='linear')
ridge = Ridge(random_state=1)
lasso = Lasso(random_state=1)
svr_rbf = SVR(kernel='rbf')
regressors = [svr_lin, lr, ridge, lasso]
stregr = StackingRegressor(regressors=regressors,meta_regressor=svr_rbf,verbose = 3)

params = {'lasso__alpha': [0.1, 1.0, 10.0],
          'ridge__alpha': [0.1, 1.0, 10.0],
                'svr__C': [0.1, 1.0, 10.0],
           'meta-svr__C': [0.1, 1.0, 10.0, 100.0],
       'meta-svr__gamma': [0.1, 1.0, 10.0]}

grid = GridSearchCV(estimator=stregr,
                    param_grid=params,
                    cv=5,
                    refit=True)

grid.fit(X, y)
for params, mean_score, scores in grid.grid_scores_:
    print("%0.3f +/- %0.2f %r"
        % (mean_score, scores.std() / 2.0, params))

# 拟合结果的评估和可视化
print("Mean Squared Error: %.4f"
% np.mean((grid.predict(X) - y) ** 2))
print('Variance Score: %.4f' % grid.score(X, y))
with plt.style.context(('seaborn-whitegrid')):
    plt.scatter(X, y, c='lightgray')
    plt.plot(X, grid.predict(X), c='darkgreen', lw=2)
plt.show()
# Out:
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=0.1, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=0.1, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=0.1, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=0.1, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=0.1, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=10.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=10.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=10.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=10.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=10.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=0.1, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=0.1, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=0.1, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=0.1, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=0.1, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=10.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=10.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=10.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=10.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=10.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=0.1, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=10.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=0.1, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=10.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=0.1, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=10.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=0.1, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=10.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=0.1, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=10.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=10.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=10.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=10.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=10.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=10.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=10.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=10.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=10.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=10.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=10.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=10.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=10.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=10.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=10.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=10.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=0.1, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=0.1, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=0.1, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=0.1, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=0.1, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=10.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=10.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=10.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=10.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=10.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=0.1, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=0.1, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=0.1, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=0.1, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=0.1, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Fitting 4 regressors...
# Fitting regressor1: svr (1/4)
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=1)
# [LibSVM]Fitting regressor2: linearregression (2/4)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitting regressor3: ridge (3/4)
# Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)
# Fitting regressor4: lasso (4/4)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
# ...
# -2.586 +/- 2.48 {'lasso__alpha': 1.0, 'meta-svr__C': 100.0, 'meta-svr__gamma': 0.1, 'ridge__alpha': 10.0, 'svr__C': 0.1}
# -2.771 +/- 2.68 {'lasso__alpha': 1.0, 'meta-svr__C': 100.0, 'meta-svr__gamma': 0.1, 'ridge__alpha': 10.0, 'svr__C': 1.0}
# -2.772 +/- 2.68 {'lasso__alpha': 1.0, 'meta-svr__C': 100.0, 'meta-svr__gamma': 0.1, 'ridge__alpha': 10.0, 'svr__C': 10.0}
# -1.902 +/- 1.93 {'lasso__alpha': 1.0, 'meta-svr__C': 100.0, 'meta-svr__gamma': 1.0, 'ridge__alpha': 0.1, 'svr__C': 0.1}
# -1.384 +/- 1.42 {'lasso__alpha': 1.0, 'meta-svr__C': 100.0, 'meta-svr__gamma': 1.0, 'ridge__alpha': 0.1, 'svr__C': 1.0}
# -1.384 +/- 1.42 {'lasso__alpha': 1.0, 'meta-svr__C': 100.0, 'meta-svr__gamma': 1.0, 'ridge__alpha': 0.1, 'svr__C': 10.0}
# -1.942 +/- 1.97 {'lasso__alpha': 1.0, 'meta-svr__C': 100.0, 'meta-svr__gamma': 1.0, 'ridge__alpha': 1.0, 'svr__C': 0.1}
# -1.387 +/- 1.42 {'lasso__alpha': 1.0, 'meta-svr__C': 100.0, 'meta-svr__gamma': 1.0, 'ridge__alpha': 1.0, 'svr__C': 1.0}
# -1.388 +/- 1.42 {'lasso__alpha': 1.0, 'meta-svr__C': 100.0, 'meta-svr__gamma': 1.0, 'ridge__alpha': 1.0, 'svr__C': 10.0}
# -2.163 +/- 2.18 {'lasso__alpha': 1.0, 'meta-svr__C': 100.0, 'meta-svr__gamma': 1.0, 'ridge__alpha': 10.0, 'svr__C': 0.1}
# -1.421 +/- 1.45 {'lasso__alpha': 1.0, 'meta-svr__C': 100.0, 'meta-svr__gamma': 1.0, 'ridge__alpha': 10.0, 'svr__C': 1.0}
# -1.420 +/- 1.45 {'lasso__alpha': 1.0, 'meta-svr__C': 100.0, 'meta-svr__gamma': 1.0, 'ridge__alpha': 10.0, 'svr__C': 10.0}
# -2.618 +/- 1.60 {'lasso__alpha': 1.0, 'meta-svr__C': 100.0, 'meta-svr__gamma': 10.0, 'ridge__alpha': 0.1, 'svr__C': 0.1}
# -8.547 +/- 5.97 {'lasso__alpha': 1.0, 'meta-svr__C': 100.0, 'meta-svr__gamma': 10.0, 'ridge__alpha': 0.1, 'svr__C': 1.0}
# -8.550 +/- 5.97 {'lasso__alpha': 1.0, 'meta-svr__C': 100.0, 'meta-svr__gamma': 10.0, 'ridge__alpha': 0.1, 'svr__C': 10.0}
# -2.609 +/- 1.55 {'lasso__alpha': 1.0, 'meta-svr__C': 100.0, 'meta-svr__gamma': 10.0, 'ridge__alpha': 1.0, 'svr__C': 0.1}
# -7.991 +/- 5.47 {'lasso__alpha': 1.0, 'meta-svr__C': 100.0, 'meta-svr__gamma': 10.0, 'ridge__alpha': 1.0, 'svr__C': 1.0}
# -8.090 +/- 5.57 {'lasso__alpha': 1.0, 'meta-svr__C': 100.0, 'meta-svr__gamma': 10.0, 'ridge__alpha': 1.0, 'svr__C': 10.0}
# -2.613 +/- 1.28 {'lasso__alpha': 1.0, 'meta-svr__C': 100.0, 'meta-svr__gamma': 10.0, 'ridge__alpha': 10.0, 'svr__C': 0.1}
# -5.431 +/- 3.35 {'lasso__alpha': 1.0, 'meta-svr__C': 100.0, 'meta-svr__gamma': 10.0, 'ridge__alpha': 10.0, 'svr__C': 1.0}
# -5.457 +/- 3.38 {'lasso__alpha': 1.0, 'meta-svr__C': 100.0, 'meta-svr__gamma': 10.0, 'ridge__alpha': 10.0, 'svr__C': 10.0}
# -9.941 +/- 6.89 {'lasso__alpha': 10.0, 'meta-svr__C': 0.1, 'meta-svr__gamma': 0.1, 'ridge__alpha': 0.1, 'svr__C': 0.1}
# -9.716 +/- 6.70 {'lasso__alpha': 10.0, 'meta-svr__C': 0.1, 'meta-svr__gamma': 0.1, 'ridge__alpha': 0.1, 'svr__C': 1.0}
# -9.716 +/- 6.70 {'lasso__alpha': 10.0, 'meta-svr__C': 0.1, 'meta-svr__gamma': 0.1, 'ridge__alpha': 0.1, 'svr__C': 10.0}
# -9.953 +/- 6.90 {'lasso__alpha': 10.0, 'meta-svr__C': 0.1, 'meta-svr__gamma': 0.1, 'ridge__alpha': 1.0, 'svr__C': 0.1}
# -9.725 +/- 6.71 {'lasso__alpha': 10.0, 'meta-svr__C': 0.1, 'meta-svr__gamma': 0.1, 'ridge__alpha': 1.0, 'svr__C': 1.0}
# -9.725 +/- 6.71 {'lasso__alpha': 10.0, 'meta-svr__C': 0.1, 'meta-svr__gamma': 0.1, 'ridge__alpha': 1.0, 'svr__C': 10.0}
# -10.035 +/- 6.93 {'lasso__alpha': 10.0, 'meta-svr__C': 0.1, 'meta-svr__gamma': 0.1, 'ridge__alpha': 10.0, 'svr__C': 0.1}
# -9.793 +/- 6.74 {'lasso__alpha': 10.0, 'meta-svr__C': 0.1, 'meta-svr__gamma': 0.1, 'ridge__alpha': 10.0, 'svr__C': 1.0}
# -9.793 +/- 6.74 {'lasso__alpha': 10.0, 'meta-svr__C': 0.1, 'meta-svr__gamma': 0.1, 'ridge__alpha': 10.0, 'svr__C': 10.0}
# -5.238 +/- 4.24 {'lasso__alpha': 10.0, 'meta-svr__C': 0.1, 'meta-svr__gamma': 1.0, 'ridge__alpha': 0.1, 'svr__C': 0.1}
# -4.240 +/- 3.29 {'lasso__alpha': 10.0, 'meta-svr__C': 0.1, 'meta-svr__gamma': 1.0, 'ridge__alpha': 0.1, 'svr__C': 1.0}
# -4.240 +/- 3.29 {'lasso__alpha': 10.0, 'meta-svr__C': 0.1, 'meta-svr__gamma': 1.0, 'ridge__alpha': 0.1, 'svr__C': 10.0}
# -5.277 +/- 4.28 {'lasso__alpha': 10.0, 'meta-svr__C': 0.1, 'meta-svr__gamma': 1.0, 'ridge__alpha': 1.0, 'svr__C': 0.1}
# -4.267 +/- 3.31 {'lasso__alpha': 10.0, 'meta-svr__C': 0.1, 'meta-svr__gamma': 1.0, 'ridge__alpha': 1.0, 'svr__C': 1.0}
# -4.266 +/- 3.31 {'lasso__alpha': 10.0, 'meta-svr__C': 0.1, 'meta-svr__gamma': 1.0, 'ridge__alpha': 1.0, 'svr__C': 10.0}
# -5.584 +/- 4.56 {'lasso__alpha': 10.0, 'meta-svr__C': 0.1, 'meta-svr__gamma': 1.0, 'ridge__alpha': 10.0, 'svr__C': 0.1}
# -4.480 +/- 3.48 {'lasso__alpha': 10.0, 'meta-svr__C': 0.1, 'meta-svr__gamma': 1.0, 'ridge__alpha': 10.0, 'svr__C': 1.0}
# -4.480 +/- 3.48 {'lasso__alpha': 10.0, 'meta-svr__C': 0.1, 'meta-svr__gamma': 1.0, 'ridge__alpha': 10.0, 'svr__C': 10.0}
# -4.649 +/- 2.88 {'lasso__alpha': 10.0, 'meta-svr__C': 0.1, 'meta-svr__gamma': 10.0, 'ridge__alpha': 0.1, 'svr__C': 0.1}
# -5.363 +/- 3.56 {'lasso__alpha': 10.0, 'meta-svr__C': 0.1, 'meta-svr__gamma': 10.0, 'ridge__alpha': 0.1, 'svr__C': 1.0}
# -5.364 +/- 3.56 {'lasso__alpha': 10.0, 'meta-svr__C': 0.1, 'meta-svr__gamma': 10.0, 'ridge__alpha': 0.1, 'svr__C': 10.0}
# -4.625 +/- 2.86 {'lasso__alpha': 10.0, 'meta-svr__C': 0.1, 'meta-svr__gamma': 10.0, 'ridge__alpha': 1.0, 'svr__C': 0.1}
# -5.344 +/- 3.55 {'lasso__alpha': 10.0, 'meta-svr__C': 0.1, 'meta-svr__gamma': 10.0, 'ridge__alpha': 1.0, 'svr__C': 1.0}
# -5.343 +/- 3.55 {'lasso__alpha': 10.0, 'meta-svr__C': 0.1, 'meta-svr__gamma': 10.0, 'ridge__alpha': 1.0, 'svr__C': 10.0}
# -4.430 +/- 2.69 {'lasso__alpha': 10.0, 'meta-svr__C': 0.1, 'meta-svr__gamma': 10.0, 'ridge__alpha': 10.0, 'svr__C': 0.1}
# -5.172 +/- 3.39 {'lasso__alpha': 10.0, 'meta-svr__C': 0.1, 'meta-svr__gamma': 10.0, 'ridge__alpha': 10.0, 'svr__C': 1.0}
# -5.172 +/- 3.39 {'lasso__alpha': 10.0, 'meta-svr__C': 0.1, 'meta-svr__gamma': 10.0, 'ridge__alpha': 10.0, 'svr__C': 10.0}
# -6.131 +/- 4.33 {'lasso__alpha': 10.0, 'meta-svr__C': 1.0, 'meta-svr__gamma': 0.1, 'ridge__alpha': 0.1, 'svr__C': 0.1}
# -5.607 +/- 3.90 {'lasso__alpha': 10.0, 'meta-svr__C': 1.0, 'meta-svr__gamma': 0.1, 'ridge__alpha': 0.1, 'svr__C': 1.0}
# -5.607 +/- 3.90 {'lasso__alpha': 10.0, 'meta-svr__C': 1.0, 'meta-svr__gamma': 0.1, 'ridge__alpha': 0.1, 'svr__C': 10.0}
# -6.150 +/- 4.34 {'lasso__alpha': 10.0, 'meta-svr__C': 1.0, 'meta-svr__gamma': 0.1, 'ridge__alpha': 1.0, 'svr__C': 0.1}
# -5.653 +/- 3.94 {'lasso__alpha': 10.0, 'meta-svr__C': 1.0, 'meta-svr__gamma': 0.1, 'ridge__alpha': 1.0, 'svr__C': 1.0}
# -5.653 +/- 3.94 {'lasso__alpha': 10.0, 'meta-svr__C': 1.0, 'meta-svr__gamma': 0.1, 'ridge__alpha': 1.0, 'svr__C': 10.0}
# -6.300 +/- 4.44 {'lasso__alpha': 10.0, 'meta-svr__C': 1.0, 'meta-svr__gamma': 0.1, 'ridge__alpha': 10.0, 'svr__C': 0.1}
# -5.957 +/- 4.14 {'lasso__alpha': 10.0, 'meta-svr__C': 1.0, 'meta-svr__gamma': 0.1, 'ridge__alpha': 10.0, 'svr__C': 1.0}
# -5.957 +/- 4.14 {'lasso__alpha': 10.0, 'meta-svr__C': 1.0, 'meta-svr__gamma': 0.1, 'ridge__alpha': 10.0, 'svr__C': 10.0}
# -0.286 +/- 0.21 {'lasso__alpha': 10.0, 'meta-svr__C': 1.0, 'meta-svr__gamma': 1.0, 'ridge__alpha': 0.1, 'svr__C': 0.1}
# -0.119 +/- 0.13 {'lasso__alpha': 10.0, 'meta-svr__C': 1.0, 'meta-svr__gamma': 1.0, 'ridge__alpha': 0.1, 'svr__C': 1.0}
# -0.119 +/- 0.13 {'lasso__alpha': 10.0, 'meta-svr__C': 1.0, 'meta-svr__gamma': 1.0, 'ridge__alpha': 0.1, 'svr__C': 10.0}
# -0.290 +/- 0.21 {'lasso__alpha': 10.0, 'meta-svr__C': 1.0, 'meta-svr__gamma': 1.0, 'ridge__alpha': 1.0, 'svr__C': 0.1}
# -0.122 +/- 0.13 {'lasso__alpha': 10.0, 'meta-svr__C': 1.0, 'meta-svr__gamma': 1.0, 'ridge__alpha': 1.0, 'svr__C': 1.0}
# -0.121 +/- 0.13 {'lasso__alpha': 10.0, 'meta-svr__C': 1.0, 'meta-svr__gamma': 1.0, 'ridge__alpha': 1.0, 'svr__C': 10.0}
# -0.263 +/- 0.19 {'lasso__alpha': 10.0, 'meta-svr__C': 1.0, 'meta-svr__gamma': 1.0, 'ridge__alpha': 10.0, 'svr__C': 0.1}
# -0.162 +/- 0.14 {'lasso__alpha': 10.0, 'meta-svr__C': 1.0, 'meta-svr__gamma': 1.0, 'ridge__alpha': 10.0, 'svr__C': 1.0}
# -0.162 +/- 0.14 {'lasso__alpha': 10.0, 'meta-svr__C': 1.0, 'meta-svr__gamma': 1.0, 'ridge__alpha': 10.0, 'svr__C': 10.0}
# -1.386 +/- 0.96 {'lasso__alpha': 10.0, 'meta-svr__C': 1.0, 'meta-svr__gamma': 10.0, 'ridge__alpha': 0.1, 'svr__C': 0.1}
# -2.041 +/- 1.58 {'lasso__alpha': 10.0, 'meta-svr__C': 1.0, 'meta-svr__gamma': 10.0, 'ridge__alpha': 0.1, 'svr__C': 1.0}
# -2.041 +/- 1.58 {'lasso__alpha': 10.0, 'meta-svr__C': 1.0, 'meta-svr__gamma': 10.0, 'ridge__alpha': 0.1, 'svr__C': 10.0}
# -1.361 +/- 0.94 {'lasso__alpha': 10.0, 'meta-svr__C': 1.0, 'meta-svr__gamma': 10.0, 'ridge__alpha': 1.0, 'svr__C': 0.1}
# -2.029 +/- 1.57 {'lasso__alpha': 10.0, 'meta-svr__C': 1.0, 'meta-svr__gamma': 10.0, 'ridge__alpha': 1.0, 'svr__C': 1.0}
# -2.029 +/- 1.57 {'lasso__alpha': 10.0, 'meta-svr__C': 1.0, 'meta-svr__gamma': 10.0, 'ridge__alpha': 1.0, 'svr__C': 10.0}
# -1.183 +/- 0.79 {'lasso__alpha': 10.0, 'meta-svr__C': 1.0, 'meta-svr__gamma': 10.0, 'ridge__alpha': 10.0, 'svr__C': 0.1}
# -1.873 +/- 1.44 {'lasso__alpha': 10.0, 'meta-svr__C': 1.0, 'meta-svr__gamma': 10.0, 'ridge__alpha': 10.0, 'svr__C': 1.0}
# -1.873 +/- 1.43 {'lasso__alpha': 10.0, 'meta-svr__C': 1.0, 'meta-svr__gamma': 10.0, 'ridge__alpha': 10.0, 'svr__C': 10.0}
# -1.775 +/- 1.14 {'lasso__alpha': 10.0, 'meta-svr__C': 10.0, 'meta-svr__gamma': 0.1, 'ridge__alpha': 0.1, 'svr__C': 0.1}
# -0.902 +/- 0.32 {'lasso__alpha': 10.0, 'meta-svr__C': 10.0, 'meta-svr__gamma': 0.1, 'ridge__alpha': 0.1, 'svr__C': 1.0}
# -0.903 +/- 0.32 {'lasso__alpha': 10.0, 'meta-svr__C': 10.0, 'meta-svr__gamma': 0.1, 'ridge__alpha': 0.1, 'svr__C': 10.0}
# -1.811 +/- 1.17 {'lasso__alpha': 10.0, 'meta-svr__C': 10.0, 'meta-svr__gamma': 0.1, 'ridge__alpha': 1.0, 'svr__C': 0.1}
# -0.923 +/- 0.33 {'lasso__alpha': 10.0, 'meta-svr__C': 10.0, 'meta-svr__gamma': 0.1, 'ridge__alpha': 1.0, 'svr__C': 1.0}
# -0.922 +/- 0.33 {'lasso__alpha': 10.0, 'meta-svr__C': 10.0, 'meta-svr__gamma': 0.1, 'ridge__alpha': 1.0, 'svr__C': 10.0}
# -2.085 +/- 1.44 {'lasso__alpha': 10.0, 'meta-svr__C': 10.0, 'meta-svr__gamma': 0.1, 'ridge__alpha': 10.0, 'svr__C': 0.1}
# -1.080 +/- 0.47 {'lasso__alpha': 10.0, 'meta-svr__C': 10.0, 'meta-svr__gamma': 0.1, 'ridge__alpha': 10.0, 'svr__C': 1.0}
# -1.079 +/- 0.47 {'lasso__alpha': 10.0, 'meta-svr__C': 10.0, 'meta-svr__gamma': 0.1, 'ridge__alpha': 10.0, 'svr__C': 10.0}
# -1.209 +/- 1.22 {'lasso__alpha': 10.0, 'meta-svr__C': 10.0, 'meta-svr__gamma': 1.0, 'ridge__alpha': 0.1, 'svr__C': 0.1}
# -0.864 +/- 0.87 {'lasso__alpha': 10.0, 'meta-svr__C': 10.0, 'meta-svr__gamma': 1.0, 'ridge__alpha': 0.1, 'svr__C': 1.0}
# -0.864 +/- 0.87 {'lasso__alpha': 10.0, 'meta-svr__C': 10.0, 'meta-svr__gamma': 1.0, 'ridge__alpha': 0.1, 'svr__C': 10.0}
# -1.218 +/- 1.23 {'lasso__alpha': 10.0, 'meta-svr__C': 10.0, 'meta-svr__gamma': 1.0, 'ridge__alpha': 1.0, 'svr__C': 0.1}
# -0.882 +/- 0.89 {'lasso__alpha': 10.0, 'meta-svr__C': 10.0, 'meta-svr__gamma': 1.0, 'ridge__alpha': 1.0, 'svr__C': 1.0}
# -0.877 +/- 0.89 {'lasso__alpha': 10.0, 'meta-svr__C': 10.0, 'meta-svr__gamma': 1.0, 'ridge__alpha': 1.0, 'svr__C': 10.0}
# -1.369 +/- 1.39 {'lasso__alpha': 10.0, 'meta-svr__C': 10.0, 'meta-svr__gamma': 1.0, 'ridge__alpha': 10.0, 'svr__C': 0.1}
# -1.033 +/- 1.05 {'lasso__alpha': 10.0, 'meta-svr__C': 10.0, 'meta-svr__gamma': 1.0, 'ridge__alpha': 10.0, 'svr__C': 1.0}
# -1.034 +/- 1.05 {'lasso__alpha': 10.0, 'meta-svr__C': 10.0, 'meta-svr__gamma': 1.0, 'ridge__alpha': 10.0, 'svr__C': 10.0}
# -0.534 +/- 0.38 {'lasso__alpha': 10.0, 'meta-svr__C': 10.0, 'meta-svr__gamma': 10.0, 'ridge__alpha': 0.1, 'svr__C': 0.1}
# -0.878 +/- 0.57 {'lasso__alpha': 10.0, 'meta-svr__C': 10.0, 'meta-svr__gamma': 10.0, 'ridge__alpha': 0.1, 'svr__C': 1.0}
# -0.876 +/- 0.57 {'lasso__alpha': 10.0, 'meta-svr__C': 10.0, 'meta-svr__gamma': 10.0, 'ridge__alpha': 0.1, 'svr__C': 10.0}
# -0.524 +/- 0.37 {'lasso__alpha': 10.0, 'meta-svr__C': 10.0, 'meta-svr__gamma': 10.0, 'ridge__alpha': 1.0, 'svr__C': 0.1}
# -0.850 +/- 0.55 {'lasso__alpha': 10.0, 'meta-svr__C': 10.0, 'meta-svr__gamma': 10.0, 'ridge__alpha': 1.0, 'svr__C': 1.0}
# -0.850 +/- 0.55 {'lasso__alpha': 10.0, 'meta-svr__C': 10.0, 'meta-svr__gamma': 10.0, 'ridge__alpha': 1.0, 'svr__C': 10.0}
# -0.446 +/- 0.33 {'lasso__alpha': 10.0, 'meta-svr__C': 10.0, 'meta-svr__gamma': 10.0, 'ridge__alpha': 10.0, 'svr__C': 0.1}
# -0.669 +/- 0.43 {'lasso__alpha': 10.0, 'meta-svr__C': 10.0, 'meta-svr__gamma': 10.0, 'ridge__alpha': 10.0, 'svr__C': 1.0}
# -0.669 +/- 0.43 {'lasso__alpha': 10.0, 'meta-svr__C': 10.0, 'meta-svr__gamma': 10.0, 'ridge__alpha': 10.0, 'svr__C': 10.0}
# -2.682 +/- 2.59 {'lasso__alpha': 10.0, 'meta-svr__C': 100.0, 'meta-svr__gamma': 0.1, 'ridge__alpha': 0.1, 'svr__C': 0.1}
# -3.012 +/- 2.92 {'lasso__alpha': 10.0, 'meta-svr__C': 100.0, 'meta-svr__gamma': 0.1, 'ridge__alpha': 0.1, 'svr__C': 1.0}
# -3.012 +/- 2.92 {'lasso__alpha': 10.0, 'meta-svr__C': 100.0, 'meta-svr__gamma': 0.1, 'ridge__alpha': 0.1, 'svr__C': 10.0}
# -2.689 +/- 2.59 {'lasso__alpha': 10.0, 'meta-svr__C': 100.0, 'meta-svr__gamma': 0.1, 'ridge__alpha': 1.0, 'svr__C': 0.1}
# -3.021 +/- 2.93 {'lasso__alpha': 10.0, 'meta-svr__C': 100.0, 'meta-svr__gamma': 0.1, 'ridge__alpha': 1.0, 'svr__C': 1.0}
# -3.019 +/- 2.92 {'lasso__alpha': 10.0, 'meta-svr__C': 100.0, 'meta-svr__gamma': 0.1, 'ridge__alpha': 1.0, 'svr__C': 10.0}
# -2.586 +/- 2.48 {'lasso__alpha': 10.0, 'meta-svr__C': 100.0, 'meta-svr__gamma': 0.1, 'ridge__alpha': 10.0, 'svr__C': 0.1}
# -2.771 +/- 2.68 {'lasso__alpha': 10.0, 'meta-svr__C': 100.0, 'meta-svr__gamma': 0.1, 'ridge__alpha': 10.0, 'svr__C': 1.0}
# -2.772 +/- 2.68 {'lasso__alpha': 10.0, 'meta-svr__C': 100.0, 'meta-svr__gamma': 0.1, 'ridge__alpha': 10.0, 'svr__C': 10.0}
# -1.902 +/- 1.93 {'lasso__alpha': 10.0, 'meta-svr__C': 100.0, 'meta-svr__gamma': 1.0, 'ridge__alpha': 0.1, 'svr__C': 0.1}
# -1.384 +/- 1.42 {'lasso__alpha': 10.0, 'meta-svr__C': 100.0, 'meta-svr__gamma': 1.0, 'ridge__alpha': 0.1, 'svr__C': 1.0}
# -1.384 +/- 1.42 {'lasso__alpha': 10.0, 'meta-svr__C': 100.0, 'meta-svr__gamma': 1.0, 'ridge__alpha': 0.1, 'svr__C': 10.0}
# -1.942 +/- 1.97 {'lasso__alpha': 10.0, 'meta-svr__C': 100.0, 'meta-svr__gamma': 1.0, 'ridge__alpha': 1.0, 'svr__C': 0.1}
# -1.387 +/- 1.42 {'lasso__alpha': 10.0, 'meta-svr__C': 100.0, 'meta-svr__gamma': 1.0, 'ridge__alpha': 1.0, 'svr__C': 1.0}
# -1.388 +/- 1.42 {'lasso__alpha': 10.0, 'meta-svr__C': 100.0, 'meta-svr__gamma': 1.0, 'ridge__alpha': 1.0, 'svr__C': 10.0}
# -2.163 +/- 2.18 {'lasso__alpha': 10.0, 'meta-svr__C': 100.0, 'meta-svr__gamma': 1.0, 'ridge__alpha': 10.0, 'svr__C': 0.1}
# -1.421 +/- 1.45 {'lasso__alpha': 10.0, 'meta-svr__C': 100.0, 'meta-svr__gamma': 1.0, 'ridge__alpha': 10.0, 'svr__C': 1.0}
# -1.420 +/- 1.45 {'lasso__alpha': 10.0, 'meta-svr__C': 100.0, 'meta-svr__gamma': 1.0, 'ridge__alpha': 10.0, 'svr__C': 10.0}
# -2.618 +/- 1.60 {'lasso__alpha': 10.0, 'meta-svr__C': 100.0, 'meta-svr__gamma': 10.0, 'ridge__alpha': 0.1, 'svr__C': 0.1}
# -8.547 +/- 5.97 {'lasso__alpha': 10.0, 'meta-svr__C': 100.0, 'meta-svr__gamma': 10.0, 'ridge__alpha': 0.1, 'svr__C': 1.0}
# -8.550 +/- 5.97 {'lasso__alpha': 10.0, 'meta-svr__C': 100.0, 'meta-svr__gamma': 10.0, 'ridge__alpha': 0.1, 'svr__C': 10.0}
# -2.609 +/- 1.55 {'lasso__alpha': 10.0, 'meta-svr__C': 100.0, 'meta-svr__gamma': 10.0, 'ridge__alpha': 1.0, 'svr__C': 0.1}
# -7.991 +/- 5.47 {'lasso__alpha': 10.0, 'meta-svr__C': 100.0, 'meta-svr__gamma': 10.0, 'ridge__alpha': 1.0, 'svr__C': 1.0}
# -8.090 +/- 5.57 {'lasso__alpha': 10.0, 'meta-svr__C': 100.0, 'meta-svr__gamma': 10.0, 'ridge__alpha': 1.0, 'svr__C': 10.0}
# -2.613 +/- 1.28 {'lasso__alpha': 10.0, 'meta-svr__C': 100.0, 'meta-svr__gamma': 10.0, 'ridge__alpha': 10.0, 'svr__C': 0.1}
# -5.431 +/- 3.35 {'lasso__alpha': 10.0, 'meta-svr__C': 100.0, 'meta-svr__gamma': 10.0, 'ridge__alpha': 10.0, 'svr__C': 1.0}
# -5.457 +/- 3.38 {'lasso__alpha': 10.0, 'meta-svr__C': 100.0, 'meta-svr__gamma': 10.0, 'ridge__alpha': 10.0, 'svr__C': 10.0}
# Mean Squared Error: 0.1845
# Variance Score: 0.7330
# D:\Softwares\Python\Anaconda\lib\site-packages\sklearn\model_selection\_search.py:747: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)
